# %% [markdown]
# <h1 style='font-size:40px'> Determinants</h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#         </li>
#     </ul>
# </div>

# %%
! git add .
! git commit -am 'Iniciar capítulo 5' 
! git push
# Out:
# [master 51c8168] Continuar listagem de ex. 13
#  1 file changed, 25 insertions(+), 25 deletions(-)
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 760 bytes | 760.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/felipesveiga/linear-algebra.git
#    c4caec4..51c8168  master -> master

# %% [markdown]
# <p style='color:red'> Terminei seção 4.4; Iniciar capítulo 5
