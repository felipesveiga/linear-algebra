# %% [markdown]
# <h1 style='font-size:40px'> Determinants</h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A determinante de uma matriz é um valor que podemos usar para obter uma série de informações sobre ela. Podemos ns fereferir a ela como $\operatorname{det}A$ ou $|A|$.
#         </li>
#         <li>
#              Este capítulo será voltado para o estudo das suas <i> propriedades</i> (5.1), <i> fórmulas</i> (5.2) e <i>aplicações</i> (5.3).
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> 5.1 The Properties of Determinants</h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Usamos essa seção para entendermos as propriedades das determinantes.
#         </li>
#     </ul>
# </div>

# %%
! git add .
! git commit -am 'Continuar "The Properties of the Determinant"' 
! git push
# Out:
# [master 206be89] Iniciar capítulo 5
#  2 files changed, 83 insertions(+), 46 deletions(-)
#  create mode 100644 05-determinants.ipynb
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 724 bytes | 724.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# To https://github.com/felipesveiga/linear-algebra.git
#    51c8168..206be89  master -> master

# %% [markdown]
# <p style='color:red'> Iniciei capítulo 5; Continuar "The Properties of the Determinant"
